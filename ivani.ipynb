# %%
A=[1,2,3,4,5]
b=list(set(A))
b.sort()
print(b)
result=[]
for i in b:
  count=0
  for j in range(len(A)):
    if i==(7-int(A[j])):
      count+=2
    elif i!=int(A[j]):
      count+=1
  result.append(count)
print(result)
print(min(result))
# Out:
# [1, 2, 3, 4, 5]
# [4, 5, 5, 5, 5]
# 4
